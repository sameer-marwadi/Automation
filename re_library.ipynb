# %%
import re

# %% [markdown]
# # Support for regular expression pattern matching

# %%
text = "The quick brown fox jumps over the lazy dog"

# %%
pattern = r"\b\w{5}\b" # Match 5 letter words

# %%
matches = re.findall(pattern, text)

# %%
print(f" the 5 letter words are {matches}")
# Out:
#  the 5 letter words are ['quick', 'brown', 'jumps']

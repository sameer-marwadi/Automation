# %%
import os

# %% [markdown]
# # list files in a directory

# %%
files = os.listdir('.')

# %%
print(files)
# Out:
# ['.anaconda', '.android', '.bash_history', '.bash_profile', '.cache', '.conda', '.condarc', '.continuum', '.docker', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.kube', '.matplotlib', '.minikube', '.ms-ad', '.python_history', '.ssh', '.streamlit', '.venv', '.virtual_documents', '.vscode', '0.26.0', "0.26.0'", 'advertising.csv', 'AIKids.ipynb', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'AskText.py', 'best_model.keras', 'BigData_Practice', 'breast_cancer.csv', 'breast_cancer_dnn_model.h5', 'busybox.yaml', 'C5_M1_PracticeLab1.ipynb', 'C5_M5_Neural_Networks_BP_GD_Practice.ipynb', 'C5_M6_Lab_SM_09172025.ipynb', 'C5_M6_Practice_Tensor_Board.ipynb', 'C5_M7_Lab_VinoHealth9182025_SM.ipynb', 'C5_M7_Practice_MLP_Pytorch_Tensor.ipynb', 'C5_Summative_Assignment_SM_09182025.ipynb', 'C6_M7_GenAI_Practice.ipynb', 'C6_M7_Lab_GenAI_SM_10232025.ipynb', 'C7_M3_Lab_SM_11082025.ipynb', 'Cap2_Pre_Visual_Analysis.ipynb', 'Capstone2_SM_1112026.ipynb', 'Capsto
# ...

# %% [markdown]
# # Create a new directory

# %%
os.mkdir('test_os')

# %%
print(files)
# Out:
# ['.anaconda', '.android', '.bash_history', '.bash_profile', '.cache', '.conda', '.condarc', '.continuum', '.docker', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.kube', '.matplotlib', '.minikube', '.ms-ad', '.python_history', '.ssh', '.streamlit', '.venv', '.virtual_documents', '.vscode', '0.26.0', "0.26.0'", 'advertising.csv', 'AIKids.ipynb', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'AskText.py', 'best_model.keras', 'BigData_Practice', 'breast_cancer.csv', 'breast_cancer_dnn_model.h5', 'busybox.yaml', 'C5_M1_PracticeLab1.ipynb', 'C5_M5_Neural_Networks_BP_GD_Practice.ipynb', 'C5_M6_Lab_SM_09172025.ipynb', 'C5_M6_Practice_Tensor_Board.ipynb', 'C5_M7_Lab_VinoHealth9182025_SM.ipynb', 'C5_M7_Practice_MLP_Pytorch_Tensor.ipynb', 'C5_Summative_Assignment_SM_09182025.ipynb', 'C6_M7_GenAI_Practice.ipynb', 'C6_M7_Lab_GenAI_SM_10232025.ipynb', 'C7_M3_Lab_SM_11082025.ipynb', 'Cap2_Pre_Visual_Analysis.ipynb', 'Capstone2_SM_1112026.ipynb', 'Capsto
# ...

# %%
# Get Current working directory

# %%
import pandas as pd

# %% [markdown]
# # Read CSV File

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Display first few rows

# %%
print(df.head())
# Out:
#    ID     Name  Age         City  Salary   Department    JoinDate
# 0   1    Alice   25     New York   70000           HR  2020-01-15
# 1   2      Bob   30  Los Angeles   80000  Engineering  2019-03-22
# 2   3  Charlie   35      Chicago   90000    Marketing  2018-07-30
# 3   4    Diana   28      Houston   75000      Finance  2021-11-10
# 4   5     Evan   40      Phoenix   95000  Engineering  2017-05-05

# %% [markdown]
# # Basic Statistics

# %%
print(df.describe())
# Out:
#              ID       Age        Salary
# count  5.000000   5.00000      5.000000
# mean   3.000000  31.60000  82000.000000
# std    1.581139   5.94138  10368.220677
# min    1.000000  25.00000  70000.000000
# 25%    2.000000  28.00000  75000.000000
# 50%    3.000000  30.00000  80000.000000
# 75%    4.000000  35.00000  90000.000000
# max    5.000000  40.00000  95000.000000

# %% [markdown]
# # Filtered Data

# %%
filtered_df = df[df['Age'] > 25]
print(filtered_df)
# Out:
#    ID     Name  Age         City  Salary   Department    JoinDate
# 1   2      Bob   30  Los Angeles   80000  Engineering  2019-03-22
# 2   3  Charlie   35      Chicago   90000    Marketing  2018-07-30
# 3   4    Diana   28      Houston   75000      Finance  2021-11-10
# 4   5     Evan   40      Phoenix   95000  Engineering  2017-05-05

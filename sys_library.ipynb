# %%
import sys

# %% [markdown]
# # Print command like arguments

# %%
print(sys.argv)
# Out:
# ['C:\\Users\\12146\\anaconda3\\Lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\12146\\AppData\\Roaming\\jupyter\\runtime\\kernel-78a73b10-3e24-4b99-aa33-05a61f1583ec.json']

# %% [markdown]
# # Get python version

# %%
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# # Exit the script

# %%
sys.exit(0)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\12146\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

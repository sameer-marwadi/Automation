# %%
from datetime import datetime,timedelta

# %% [markdown]
# # Get current Date & Time

# %%
now = datetime.now()

# %%
print(f"Current time :{now}")
# Out:
# Current time :2026-04-04 13:44:10.932159

# %% [markdown]
# # Date Arithmetic

# %%
now +

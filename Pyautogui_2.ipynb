# %%
import pyautogui
pyautogui.moveTo(100, 300, duration=1)
pyautogui.click()
# Type Text
pyautogui.typewrite("Hello, PyAutogui!")
pyautogui.typewrite("Hello, PyAutogui!")
pyautogui.typewrite("Hello, PyAutogui!")
pyautogui.typewrite("Hello, PyAutogui!")
screenshot = pyautogui.screenshot()
screenshot.save('screenshot.png')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\12146\AppData\Local\Temp\ipykernel_79744\2663655076.py:5: SyntaxWarning: invalid escape sequence '\ '
#   pyautogui.typewrite("Hello, PyAutogui! \ I am conducting a test")
